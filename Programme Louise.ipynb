# %%
#Tableau
tableau = [1,2,3,4,5]

# %%
tableau[0] + tableau[1] + tableau[2] + tableau[3] + tableau[4]
# Out:
# 15

# %%
import copy

titi = copy.copy(tableau)
titi[2]
# Out:
# 30

# %%
titi[2] = 60

# %%
tableau
# Out:
# [1, 2, 30, 4, 5]

# %%
titi
# Out:
# [1, 2, 60, 4, 5]

# %%
for i in range(len(titi)):
    print(titi[i])
# Out:
# 1
# 2
# 60
# 4
# 5

# %%
import math;
def isPrime(n):
    if (math.floor(n) != n):
        print("Un nombre premier est forcément un entier.")
        return False;
    else:
        if (n<=3):
            print(n, "est premier !");
            return True;
        else:
            i = 2;
            while i < n:
                if (n%i == 0):
                    print(n, "n'est PAS premier.");
                    return False;
                i = i + 1
            print(n, "est premier !");
            return True;

# %%
isPrime(2003)
# Out:
# 2003 est premier !
# True

# %%
test = range(0,900)

# %%
res = [];
for i in test:
    res.append(isPrime(i));
# Out:
# 0 est premier !
# 1 est premier !
# 2 est premier !
# 3 est premier !
# 4 n'est PAS premier.
# 5 est premier !
# 6 n'est PAS premier.
# 7 est premier !
# 8 n'est PAS premier.
# 9 n'est PAS premier.
# 10 n'est PAS premier.
# 11 est premier !
# 12 n'est PAS premier.
# 13 est premier !
# 14 n'est PAS premier.
# 15 n'est PAS premier.
# 16 n'est PAS premier.
# 17 est premier !
# 18 n'est PAS premier.
# 19 est premier !
# 20 n'est PAS premier.
# 21 n'est PAS premier.
# 22 n'est PAS premier.
# 23 est premier !
# 24 n'est PAS premier.
# 25 n'est PAS premier.
# 26 n'est PAS premier.
# 27 n'est PAS premier.
# 28 n'est PAS premier.
# 29 est premier !
# 30 n'est PAS premier.
# 31 est premier !
# 32 n'est PAS premier.
# 33 n'est PAS premier.
# 34 n'est PAS premier.
# 35 n'est PAS premier.
# 36 n'est PAS premier.
# 37 est premier !
# 38 n'est PAS premier.
# 39 n'est PAS premier.
# 40 n'est PAS premier.
# 41 est premier !
# 42 n'est PAS premier.
# 43 est premier !
# 44 n'est PAS premier.
# ...

# %%
# %matplotlib inline

import matplotlib;
import matplotlib.pyplot as pl;

point = [];
for i in res:
    #print(i);
    if (i == True):
        point.append(1);
    else:
        point.append(0);

point
pl.plot(point);
